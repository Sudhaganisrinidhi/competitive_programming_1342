# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudhaganisrinidhi/competitive_programming_1342/blob/main/week2_dynamicprogramming_mon_1342.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fibonacci(n, memo):
    if n in memo:
        return memo[n]
    if n == 0:
        return 0
    if n == 1:
        return 1
    memo[n] = fibonacci(n - 1, memo) + fibonacci(n - 2, memo)
    return memo[n]
n = int(input())
memo = {}
result = fibonacci(n, memo)
print(result)
# Out:
# 10
# 55
